# %% [markdown]
# ![logo-gt.png](attachment:logo-gt.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>BIOS 4150/BIOL 6150</h1>
#     <h3>Instructor: Dr. King Jordan</h3>
#     <p>TAs: Shivam Sharma (shivamsharma13@gatech.edu) & Vishva Natarajan (vishvanata@gatech.edu)</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2>Project 1 (Data access & QC) starter notebook</h2>
#     <h3>Deadline: 12:00AM, October 20th, 2023</h3>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # **1. Your assigned 1000 Genomes individual**
# ### *Total Questions: 3*
# ### *Total Points: 10+10+20 = 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.1 Does you group have an assigned individual ID from the 1000 Genomes Project?</h3>
#     <p>Find the individual on the international genomes website and paste a screenshot below</p>
# </div>

# %% [markdown]
# ##Add image here for 1.1
# ![P1.png](attachment:P1.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.2 What population does you assigned individual belong to?</h3>
#     <p>Write about where the geographical location of where this individual lived at the time of recruitment? </p>
# </div>

# %%
#Write about the individual and their ancestors here.
The individual is a male and he belongs from African Ancestry in Southwest US.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.3 More about your individual's population?</h3>
#     <p>Read more about this population and write about their recent historical  (100-500 years) ancestors.</p>
# </div>

# %%
#Write about the individual and their ancestors here.
As mentioned, the individual belongs to african ancestry. 
The individual is a male (father). At least three out of four grandparents identified themselves as african-american.

# %% [markdown]
# # **2. Exome sequencing**
# ### *Total Questions: 3*
# ### *Total Points: 20+20= 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.1 Does your assigned individual has exome sequencing data? If yes, then what is the SRR ID for that sequencing run?</h3>
#     <p>Does you individual have multiple SRR IDs? In case they do, which one would you pick? (Hint: The sequencing information is coming from the same individual; but larger file size might be more preferable)</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h3>Multiple fastq files for your 1KGP individual</h3>
#     <p>On the FTP server, it is expected that you will have more than 1 pair of fastq files. What you need to decide on is which set of fastq files make the most sense. A few good checks are the size of the file (maybe 1-12GB), presence of an SRR ID, elimination of exceptionally small files etc. </p>
#     <p>If your team is still confused, please reach out to us regarding this.</p>
# </div>

# %%
#Write the SRR ID here along with your reasoning for selection.
We have selected (SRR029903_1.filt.fastq.gz, SRR029903_2.filt.fastq.gz) because these are paired end sequence data.So, these
gives us the two readings (forward/reverse). Larger files (1.1GB) in the population represents more diversity in individual.
Also, the larger files may have more individual genome sequenced.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.2 Looking at just the exome sequencing of this individual, how many variants would you expect them to carry compared to the reference genome?</h3>
#     <p>Keep in mind this is 1 individual, and learn about the expected number of variants from WGS, WES, and Genotyping</p>
# </div>

# %%
#Write about the variant information here.
While the count of variants in a Whole Exome Sequencing (WES) dataset can fluctuate significantly
due to factors like read depth and read quality, a standard WES dataset typically encompasses 
approximately 100,000 to 130,000 variants for an individual. However, to obtain an accurate count of variants, 
the process of variant calling must be carried out.

# %% [markdown]
# # **3. Data access**
# ### *Total Questions: 3*
# ### *Total Points: 20+20 = 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>3.1 Download the exome sequencing data for this individual and write the size of the files?</h3>
#     <p>3.1.1 How many files do you have? Is the sequencing paired?</p>
#     <p>3.1.2 How many reads are present in each file? </p>
# </div>

# %%
#Show you download commamd.
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19908/sequence_read/SRR029902_1.filt.fastq.gz
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19908/sequence_read/SRR029902_2.filt.fastq.gz

# %%
#Move the files to an appropriate place and 'ls' that directory. We want to see the file names and the file sizes
# !mkdir -p ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/fastQCBeforeTrimming
# !mkdir -p ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/Trimming
# !mkdir -p ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/fastQCAfterTrimming

# %%
#'ls' that directory
# !ls -l
# Out:
# total 2119620
# drwxr-xr-x 2 hpatil39 gtperson       4096 Oct 20 23:35 fastQCAfterTrimming
# drwxr-xr-x 2 hpatil39 gtperson       4096 Oct 20 14:55 fastQCBeforeTrimming
# -rw-r--r-- 1 hpatil39 gtperson    2987480 Oct 20 23:47 P1 copy_trash_book.ipynb
# -rw-r--r-- 1 hpatil39 gtperson    2987480 Oct 20 23:45 Project1-DataAccessQC (1).ipynb
# -rw-r--r-- 1 hpatil39 gtperson 1076416578 Oct 20 14:39 SRR029902_1.filt.fastq.gz
# -rw-r--r-- 1 hpatil39 gtperson 1079551817 Oct 20 14:40 SRR029902_2.filt.fastq.gz
# drwxr-xr-x 2 hpatil39 gtperson       4096 Oct 20 23:51 Trimming

# %%
#Write about the fastq file here.
FastQC is a bioinformatics tool used to assess the quality of high-throughput sequencing data.
It provides comprehensive quality metrics and generates graphical reports to check potential issues
in raw sequencing data, such as poor-quality reads, overrepresented sequences, and adapter contamination.

# %%
#Write about the fastq file here.
FastQC is a bioinformatics tool used to assess the quality of high-throughput sequencing data.
It provides comprehensive quality metrics and generates graphical reports to check potential issues
in raw sequencing data, such as poor-quality reads, overrepresented sequences, and adapter contamination.

# %% [markdown]
# # **4. Pre-QC with FastQC**
# ### *Total Questions: 2*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.1 Show your exact command below.</h3>
# </div>

# %%
#Command here.
# !fastqc -o ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/fastQCBeforeTrimming/ ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/SRR029902_1.filt.fastq.gz ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/SRR029902_2.filt.fastq.gz
# Out:
# application/gzip
# application/gzip
# Started analysis of SRR029902_1.filt.fastq.gz
# Approx 5% complete for SRR029902_1.filt.fastq.gz
# Approx 10% complete for SRR029902_1.filt.fastq.gz
# Approx 15% complete for SRR029902_1.filt.fastq.gz
# Approx 20% complete for SRR029902_1.filt.fastq.gz
# Approx 25% complete for SRR029902_1.filt.fastq.gz
# Approx 30% complete for SRR029902_1.filt.fastq.gz
# Approx 35% complete for SRR029902_1.filt.fastq.gz
# Approx 40% complete for SRR029902_1.filt.fastq.gz
# Approx 45% complete for SRR029902_1.filt.fastq.gz
# Approx 50% complete for SRR029902_1.filt.fastq.gz
# Approx 55% complete for SRR029902_1.filt.fastq.gz
# Approx 60% complete for SRR029902_1.filt.fastq.gz
# Approx 65% complete for SRR029902_1.filt.fastq.gz
# Approx 70% complete for SRR029902_1.filt.fastq.gz
# Approx 75% complete for SRR029902_1.filt.fastq.gz
# Approx 80% complete for SRR029902_1.filt.fastq.gz
# Approx 85% complete for SRR029902_1.filt.fastq.gz
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.2 Show <i>per base sequencing quality</i>?</h3>
#     <p>Add a screenshot below</p>
# </div>

# %% [markdown]
# ##Add image here for 4.1
# ![ney1.png](attachment:ney1.png)

# %% [markdown]
# ##Add image here for 4.1
# ![vk1.png](attachment:vk1.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.3 Show <i>Per base sequence content</i>?</h3>
#     <p>Add a screenshot below</p>
# </div>

# %% [markdown]
# ##Add image here for 4.2
# ![pha1.png](attachment:pha1.png)

# %% [markdown]
# ##Add image here for 4.2
# ![pha2.png](attachment:pha2.png)

# %% [markdown]
# # **5. Trimming with fastp or trimmmomatic**
# ### *Total Questions: 3*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.1 What was the tools and command you used?</h3>
#     <p>Write the tool name and exact command below</p>
# </div>

# %%
#Exact command here
The tool here is used fastp.
# !fastp -i ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/SRR029902_1.filt.fastq.gz -I ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/SRR029902_2.filt.fastq.gz -o ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/Trimming/SRR029902_1.Trimmed.fastq.gz -O ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/Trimming/SRR029902_2.Trimmed.fastq.gz -f 12 -t 15

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.2 How did you perform the trimming?</h3>
#     <p>Did you use dynamic built in features or hard coded parameters?</p>
#     <p>Did you have to go back and repeat the trimming after run(s) for <b>postQC?</b></p>
# </div>

# %% [markdown]
# #Write here
# We couldnt access the fastp in the server. Hence, we run the fastp in our terminal and got the following output.
# We have used hard coded parameters because fastp uses configured parameters rather than dynamic features.
# No, we have not gone back and repeat the trimming after runs for postQC.
# ![Fastp1.png](attachment:Fastp1.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.3 What percentage of reads did you lose in the trimming process?</h3>
#     <p>5.3.1 Write the total number of reads before and after trimming</p>
#     <p>5.3.2 If you had a paired fastq file, are there any reads after trimming present in one file and not the other? (eg: present in reverse but not in forward?)</p>
#
# </div>

# %%
#Before trimming: 

The % of reads lost = 11.08%
Read1 before filtering:
total reads: 14513246
total bases: 1103006696
Q20 bases: 961282123(87.1511%)
Q30 bases: 650320751(58.9589%)
    
Read2 before filtering:
total reads: 14513246
total bases: 1103006696
Q20 bases: 949128155(86.0492%)
Q30 bases: 667358829(60.5036%)
    
#After trimming:
Read1 after filtering:
total reads: 12904787
total bases: 632091163
Q20 bases: 598551253(94.6938%)
Q30 bases: 422017801(66.7653%)
    
Read2 after filtering:
total reads: 12904787
total bases: 632091163
Q20 bases: 594156315(93.9985%)
Q30 bases: 433578840(68.5944%)

Filtering result:
reads passed filter: 25809574
reads failed due to low quality: 3216916
reads failed due to too many N: 2
reads failed due to too short: 0
reads with adapter trimmed: 432690
bases trimmed due to adapters: 515678

Duplication rate: 4.2468%

Insert size peak (evaluated by paired-end reads): 91Filtering result:
reads passed filter: 25809574
reads failed due to low quality: 3216916
reads failed due to too many N: 2
reads failed due to too short: 0
reads with adapter trimmed: 432690
bases trimmed due to adapters: 515678

Duplication rate: 4.2468%
Insert size peak (evaluated by paired-end reads): 91
    
I believe there are no difference after trimming which is present in one file not in the other.

# %% [markdown]
# # **6. Post-QC with FastQC?**
# ### *Total Questions: 2*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.1 Show your exact command below.</h3>
# </div>

# %%
# !fastqc -o ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/fastQCAfterTrimming/ ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/SRR029902_1.Trimmed.fastq ~/biol6150/ProjectSubmissions/Group14-Peaches/Project1/SRR029902_2.Trimmed.fastq
# Out:
# null
# null
# Started analysis of SRR029902_1.Trimmed.fastq
# Approx 5% complete for SRR029902_1.Trimmed.fastq
# Approx 10% complete for SRR029902_1.Trimmed.fastq
# Approx 15% complete for SRR029902_1.Trimmed.fastq
# Approx 20% complete for SRR029902_1.Trimmed.fastq
# Approx 25% complete for SRR029902_1.Trimmed.fastq
# Approx 30% complete for SRR029902_1.Trimmed.fastq
# Approx 35% complete for SRR029902_1.Trimmed.fastq
# Approx 40% complete for SRR029902_1.Trimmed.fastq
# Approx 45% complete for SRR029902_1.Trimmed.fastq
# Approx 50% complete for SRR029902_1.Trimmed.fastq
# Approx 55% complete for SRR029902_1.Trimmed.fastq
# Approx 60% complete for SRR029902_1.Trimmed.fastq
# Approx 65% complete for SRR029902_1.Trimmed.fastq
# Approx 70% complete for SRR029902_1.Trimmed.fastq
# Approx 75% complete for SRR029902_1.Trimmed.fastq
# Approx 80% complete for SRR029902_1.Trimmed.fastq
# Approx 85% complete for SRR029902_1.Trimmed.fastq
# Approx 90% complete for SRR029902_1.Trimmed.fastq
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.2 Show <i>per base sequencing quality</h3>
#     <p>If the quality was falling below 20 for certain regions then trim it. Add a screenshot below</p>
# </div>

# %% [markdown]
# ##Add image here for 6.1
# ![trim1.png](attachment:trim1.png)

# %% [markdown]
# ##Add image here for 6.1
# ![trim2.png](attachment:trim2.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.3 Show <i>Per base sequence content</i>?</h3>
#     <p>Ideally we shouldn't see adapters at the beginning of the reads in the fastq files. Add a screenshot below</p>
# </div>

# %% [markdown]
# ##Add image here for 6.2
# ![trim3.png](attachment:trim3.png)

# %% [markdown]
# ##Add image here for 6.2
# ![trim4.png](attachment:trim4.png)
